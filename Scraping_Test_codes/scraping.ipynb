# %%
import requests, time

# %%
standings_url = "https://fbref.com/en/comps/31/Liga-MX-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# Out:
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\4209044294.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
matches
# Out:
#           Date   Time     Comp                         Round  Day Venue  \
# 0   2024-07-06  21:00  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 1   2024-07-13  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 2   2024-07-16  21:05  Liga MX  Apertura 2024 Regular Season  Tue  Home
# 3   2024-07-20  21:05  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 4   2024-08-23  19:00  Liga MX  Apertura 2024 Regular Season  Fri  Away
# 5   2024-08-31  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 6   2024-09-14  20:35  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 7   2024-09-17  19:00  Liga MX  Apertura 2024 Regular Season  Tue  Away
# 8   2024-09-21  21:05  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 9   2024-09-28  19:05  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 10  2024-10-05  17:00  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 11  2024-10-18  21:05  Liga MX  Apertura 2024 Regular Season  Fri  Away
# 12  2024-10-23  19:00  Liga MX  Apertura 2024 Regular Season  Wed  Home
# 13  2024-10-26  19:00  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 14  2024-11-02  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 15  2024-11-06  21:05  Liga MX  Apertura 2024 Regular Season  Wed  Away
# 16  2024-11-09  21:05  Liga MX  Apertura 2024 Regular Season  Sat  Home
#
#    Result   GF   GA     Opponent   xG  xGA  Poss  Attendance  \
# 0       W  1.0  0.0     Mazatlán  2.0  0.6  65.0     15206.0
# 1       W  4.0  0.0    Monterrey  1.9  0.4  54.0     45957.0
# 2       W  3.0  0.0      Tijuana  2.2  0.5  39.0         NaN
# 3       D  1.0  1.0       Toluca  1.7  0.6  67.0         NaN
# 4       W  2.0  0.0    Querétaro  2.0  0.3  63.0         NaN
# 5       W  4.0  1.0      América  0.9  0.7  54.0         NaN
# 6       W  2.0  1.0         León  2.0  1.3  57.0         NaN
# 7       L  1.0  3.0     Atlético  0.6  2.7  56.0         NaN
# 8       W  1.0  0.0  Guadalajara  1.9  0.8  56.0         NaN
# 9       W  4.0  2.0      Pachuca  2.4  1.8  70.0         NaN
# 10      W  3.0  0.0       Necaxa  1.9  0.7  68.0         NaN
# 11      W  2.0  1.0       Puebla  2.4  0.4  62.0         NaN
# 12      W  4.0  0.0    FC Juárez  2.9  0.3  63.0         NaN
# 13    NaN  NaN  NaN         UNAM  NaN  NaN   NaN         NaN
# 14    NaN  NaN  NaN       Santos  NaN  NaN   NaN         NaN
# 15    NaN  NaN  NaN        Atlas  NaN  NaN   NaN         NaN
# 16    NaN  NaN  NaN         UANL  NaN  NaN   NaN         NaN
#
#              Captain Formation Opp Formation               Referee  \
# 0     Ignacio Rivero     5-4-1       4-2-3-1                   NaN
# 1     Ignacio Rivero   4-1-4-1         4-4-2                   NaN
# 2     Ignacio Rivero     3-4-3       4-2-3-1                   NaN
# 3     Ignacio Rivero     5-3-2       4-2-3-1                   NaN
# 4     Ignacio Rivero   3-1-4-2         3-5-2                   NaN
# 5          Erik Lira   3-1-4-2         3-4-3    César Arturo Ramos
# 6   Charly Rodríguez   3-1-4-2     4-1-2-1-2  Maximiliano Quintero
# 7     Ignacio Rivero   3-1-4-2       4-2-3-1           Oscar Mejia
# 8     Ignacio Rivero     5-4-1       4-1-3-2       Daniel Quintero
# 9     Ignacio Rivero   3-1-4-2       4-1-4-1       Adonai Escobedo
# 10  Charly Rodríguez   3-1-4-2       4-3-1-2     Guillermo Pacheco
# 11  Charly Rodríguez   3-1-4-2         5-3-2      Charles Terrazas
# 12  Charly Rodríguez     3-4-3         4-3-3          Vicente Arce
# 13               NaN       NaN           NaN                   NaN
# 14               NaN       NaN           NaN                   NaN
# 15               NaN       NaN           NaN                   NaN
# 16               NaN       NaN           NaN                   NaN
#
#     Match Report  Notes
# 0   Match Report    NaN
# 1   Match Report    NaN
# 2   Match Report    NaN
# 3   Match Report    NaN
# 4   Match Report    NaN
# 5   Match Report    NaN
# 6   Match Report    NaN
# 7   Match Report    NaN
# 8   Match Report    NaN
# 9   Match Report    NaN
# 10  Match Report    NaN
# 11  Match Report    NaN
# 12  Match Report    NaN
# 13  Head-to-Head    NaN
# 14  Head-to-Head    NaN
# 15  Head-to-Head    NaN
# 16  Head-to-Head    NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/632f1838/2024-2025/matchlogs/all_comps/shooting/Cruz-Azul-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
data
# Out:
# <Response [200]>

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
# Out:
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\2517714723.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Cruz Azul                                                           \
#            Date   Time     Comp                         Round  Day Venue
# 0    2024-07-06  21:00  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 1    2024-07-13  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 2    2024-07-16  21:05  Liga MX  Apertura 2024 Regular Season  Tue  Home
# 3    2024-07-20  21:05  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 4    2024-08-23  19:00  Liga MX  Apertura 2024 Regular Season  Fri  Away
#
#                                ... Standard             Expected               \
#   Result   GF   GA   Opponent  ...     Dist FK PK PKatt       xG npxG npxG/Sh
# 0      W  1.0  0.0   Mazatlán  ...     18.6  0  0     0      2.0  2.0    0.12
# 1      W  4.0  0.0  Monterrey  ...     19.1  1  1     1      1.9  1.1    0.08
# 2      W  3.0  0.0    Tijuana  ...     17.1  0  0     0      2.2  2.2    0.14
# 3      D  1.0  1.0     Toluca  ...     16.9  1  0     0      1.7  1.7    0.08
# 4      W  2.0  0.0  Querétaro  ...     19.6  0  1     1      2.0  1.2    0.06
#
#                Unnamed: 25_level_0
#   G-xG np:G-xG        Match Report
# 0 -1.0    -1.0        Match Report
# 1  2.1     1.9        Match Report
# 2  0.8     0.8        Match Report
# 3 -0.7    -0.7        Match Report
# 4  0.0    -0.2        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time     Comp                         Round  Day Venue Result  \
# 0  2024-07-06  21:00  Liga MX  Apertura 2024 Regular Season  Sat  Home      W
# 1  2024-07-13  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Away      W
# 2  2024-07-16  21:05  Liga MX  Apertura 2024 Regular Season  Tue  Home      W
# 3  2024-07-20  21:05  Liga MX  Apertura 2024 Regular Season  Sat  Home      D
# 4  2024-08-23  19:00  Liga MX  Apertura 2024 Regular Season  Fri  Away      W
#
#     GF   GA   Opponent  ...  Opp Formation  Referee  Match Report  Notes  Sh  \
# 0  1.0  0.0   Mazatlán  ...        4-2-3-1      NaN  Match Report    NaN  16
# 1  4.0  0.0  Monterrey  ...          4-4-2      NaN  Match Report    NaN  14
# 2  3.0  0.0    Tijuana  ...        4-2-3-1      NaN  Match Report    NaN  17
# 3  1.0  1.0     Toluca  ...        4-2-3-1      NaN  Match Report    NaN  21
# 4  2.0  0.0  Querétaro  ...          3-5-2      NaN  Match Report    NaN  22
#
#   SoT  Dist FK PK  PKatt
# 0   7  18.6  0  0      0
# 1   7  19.1  1  1      1
# 2   6  17.1  0  0      0
# 3   5  16.9  1  0      0
# 4   4  19.6  0  1      1
#
# [5 rows x 26 columns]

# %%
years = list(range(2024, 2023, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/31/Liga-MX-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    time.sleep(1)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]
    links = [l.get("href") for l in standings_table.find_all('a')]
    time.sleep(1)
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    time.sleep(1)
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Liga MX"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(12)
# Out:
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\edgar\AppData\Local\Temp\ipykernel_28388\494240084.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
len(all_matches)
# Out:
# 18

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time     comp                         round  day venue  \
# 0   2024-07-06  21:00  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 1   2024-07-13  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 2   2024-07-16  21:05  Liga MX  Apertura 2024 Regular Season  Tue  Home
# 3   2024-07-20  21:05  Liga MX  Apertura 2024 Regular Season  Sat  Home
# 4   2024-08-23  19:00  Liga MX  Apertura 2024 Regular Season  Fri  Away
# ..         ...    ...      ...                           ...  ...   ...
# 8   2024-09-22  19:05  Liga MX  Apertura 2024 Regular Season  Sun  Home
# 9   2024-09-28  21:10  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 10  2024-10-06  20:05  Liga MX  Apertura 2024 Regular Season  Sun  Home
# 11  2024-10-19  19:05  Liga MX  Apertura 2024 Regular Season  Sat  Away
# 12  2024-10-22  19:00  Liga MX  Apertura 2024 Regular Season  Tue  Home
#
#    result   gf   ga   opponent  ...  match report  notes  sh  sot  dist fk pk  \
# 0       W  1.0  0.0   Mazatlán  ...  Match Report    NaN  16    7  18.6  0  0
# 1       W  4.0  0.0  Monterrey  ...  Match Report    NaN  14    7  19.1  1  1
# 2       W  3.0  0.0    Tijuana  ...  Match Report    NaN  17    6  17.1  0  0
# 3       D  1.0  1.0     Toluca  ...  Match Report    NaN  21    5  16.9  1  0
# 4       W  2.0  0.0  Querétaro  ...  Match Report    NaN  22    4  19.6  0  1
# ..    ...  ...  ...        ...  ...           ...    ...  ..  ...   ... .. ..
# 8       W  2.0  0.0     Toluca  ...  Match Report    NaN   7    4  19.4  2  0
# 9       L  1.0  3.0   Atlético  ...  Match Report    NaN   8    5  17.6  1  0
# 10      L  0.0  2.0  FC Juárez  ...  Match Report    NaN  12    4  17.6  0  0
# 11      L  0.0  3.0    América  ...  Match Report    NaN   5    3  16.4  0  0
# 12      D  1.0  1.0    Pachuca  ...  Match Report    NaN   9    5  21.1  1  0
#
#    pkatt season           team
# 0      0   2024      Cruz Azul
# 1      1   2024      Cruz Azul
# 2      0   2024      Cruz Azul
# 3      0   2024      Cruz Azul
# 4      1   2024      Cruz Azul
# ..   ...    ...            ...
# 8      0   2024  Santos Laguna
# 9      0   2024  Santos Laguna
# 10     0   2024  Santos Laguna
# 11     0   2024  Santos Laguna
# 12     0   2024  Santos Laguna
#
# [236 rows x 28 columns]

# %% [raw]
# Obtener el los proximos partidos

# %%
match_df["date"]

# %%
match_df.to_csv("matchesLMX.csv")
