# %%
import pandas as pd

# %%
matches = pd.read_csv("matchesSemiFinals.csv", index_col=0)

# %%
matches = matches.drop(columns=["opp formation"])

# %%
matches.head()
# Out:
#         team     opponent        date venue   time comp round  day result  \
# 0    America      Tijuana  2025-01-16  Home  20:10  NaN   NaN  NaN    NaN
# 1     Puebla     Atletico  2025-01-17  Home  19:00  NaN   NaN  NaN    NaN
# 2       UANL     Mazatlan  2025-01-17  Home  21:00  NaN   NaN  NaN    NaN
# 3     Necaxa  Guadalajara  2025-01-17  Home  21:05  NaN   NaN  NaN    NaN
# 4  Queretaro   Pumas UNAM  2025-01-19  Home  17:00  NaN   NaN  NaN    NaN
#
#     gf  ... referee  match report  notes  sh  sot dist  fk  pk pkatt season
# 0  NaN  ...     NaN           NaN    NaN NaN  NaN  NaN NaN NaN   NaN    NaN
# 1  NaN  ...     NaN           NaN    NaN NaN  NaN  NaN NaN NaN   NaN    NaN
# 2  NaN  ...     NaN           NaN    NaN NaN  NaN  NaN NaN NaN   NaN    NaN
# 3  NaN  ...     NaN           NaN    NaN NaN  NaN  NaN NaN NaN   NaN    NaN
# 4  NaN  ...     NaN           NaN    NaN NaN  NaN  NaN NaN NaN   NaN    NaN
#
# [5 rows x 27 columns]

# %%
matches["team"].value_counts()
# Out:
# team
# America          72
# Monterrey        64
# UANL             63
# Cruz Azul        62
# Pumas UNAM       61
# Atletico         61
# Guadalajara      59
# Toluca           57
# Pachuca          56
# Tijuana          56
# Atlas            55
# Puebla           55
# Necaxa           55
# Leon             55
# Queretaro        54
# Santos Laguna    54
# FC Juarez        53
# Mazatlan         53
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Cruz Azul"].sort_values("date")
# Out:
#           team opponent        date venue   time     comp  \
# 648  Cruz Azul    Atlas  2023-07-01  Away  22:10  Liga MX
# 649  Cruz Azul   Toluca  2023-07-08  Home  18:50  Liga MX
# 650  Cruz Azul  Tijuana  2023-07-14  Away  20:10  Liga MX
# 651  Cruz Azul   Santos  2023-08-20  Home  18:00  Liga MX
# 652  Cruz Azul  Pachuca  2023-08-23  Away  20:06  Liga MX
# ..         ...      ...         ...   ...    ...      ...
# 26   Cruz Azul  Tijuana  2024-11-27  Away  19:10  Liga MX
# 27   Cruz Azul  Tijuana  2024-11-30  Home  19:10  Liga MX
# 28   Cruz Azul  América  2024-12-05  Away  20:00  Liga MX
# 29   Cruz Azul  América  2024-12-08  Home  19:00  Liga MX
# 30   Cruz Azul    Atlas  2025-01-11  Home  21:05  Liga MX
#
#                             round  day result   gf  ...               referee  \
# 648  Apertura 2023 Regular Season  Sat      L    0  ...        Víctor Cáceres
# 649  Apertura 2023 Regular Season  Sat      L    0  ...          Ismael Lopez
# ...

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2025-01-13']
#train = matches[(matches["date"] >= '2024-11-05') & (matches["date"] <= '2024-11-10')]

# %%
#test = matches[(matches["date"] >= '2025-01-05') & (matches["date"] <= '2025-01-13')]
test = matches[(matches["date"] >= '2025-01-13')]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
preds
# Out:
# array([0, 0, 1, 0, 0, 0, 0, 1, 1])

# %%
probabilidades = rf.predict_proba(test[predictors])

# %%
df_resultados = pd.DataFrame(probabilidades, columns=rf.classes_)
df_resultados['Prediccion'] = rf.predict(test[predictors])
df_resultados = df_resultados.reset_index(drop=True)
test = test.reset_index(drop=True)
df_resultados['Equipo'] = test['team']
df_resultados['Oponente'] = test['opponent']
df_resultados['Fecha']= test['date']

# %%
df_resultados
# Out:
#           0         1  Prediccion     Equipo       Oponente      Fecha
# 0  0.511906  0.488094           0    America        Tijuana 2025-01-16
# 1  0.681434  0.318566           0     Puebla       Atletico 2025-01-17
# 2  0.390928  0.609072           1       UANL       Mazatlan 2025-01-17
# 3  0.507267  0.492733           0     Necaxa    Guadalajara 2025-01-17
# 4  0.503439  0.496561           0  Queretaro     Pumas UNAM 2025-01-19
# 5  0.632581  0.367419           0     Toluca      Monterrey 2025-01-18
# 6  0.660285  0.339715           0  FC Juarez      Cruz Azul 2025-01-18
# 7  0.393280  0.606720           1      Atlas           León 2025-01-18
# 8  0.274104  0.725896           1    Pachuca  Santos Laguna 2025-01-20

# %% [markdown]
# Evaluar exactitud

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy= accuracy_score(test["target"], preds)

# %%
accuracy
# Out:
# 0.6666666666666666

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted  0  1
# actual
# 0          6  3

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.0

# %%
# Calcular la precisión de la clase "Gana el equipo local" (1)
precision_local = precision_score(test["venue_code"], preds, pos_label=1)

print("Precisión para las predicciones de 'Gana el equipo local':", precision_local)
# Out:
# Precisión para las predicciones de 'Gana el equipo local': 1.0

# %% [markdown]
# Considerar solo los esenarios en que el modelo coincide con el ganador y el perdedor

# %% [markdown]
# Calcula El dinero a pagar

# %%
# Define la cantidad inicial de dinero
dinero = 400

# %%
# Descarta los partidos predecidos donde el ganador es el visitante
df_resultados[1] = df_resultados[1]*df_resultados['Prediccion']
# Calcula la suma total de las probabilidades de ganar local
suma_probabilidades_local = df_resultados[1].sum()
# Calcula la apuesta para cada fila
df_resultados['Apuesta'] = (df_resultados[1] / suma_probabilidades_local) * dinero
print(df_resultados)
# Out:
#           0         1  Prediccion     Equipo       Oponente      Fecha  \
# 0  0.511906  0.000000           0    America        Tijuana 2025-01-16
# 1  0.681434  0.000000           0     Puebla       Atletico 2025-01-17
# 2  0.390928  0.609072           1       UANL       Mazatlan 2025-01-17
# 3  0.507267  0.000000           0     Necaxa    Guadalajara 2025-01-17
# 4  0.503439  0.000000           0  Queretaro     Pumas UNAM 2025-01-19
# 5  0.632581  0.000000           0     Toluca      Monterrey 2025-01-18
# 6  0.660285  0.000000           0  FC Juarez      Cruz Azul 2025-01-18
# 7  0.393280  0.606720           1      Atlas           León 2025-01-18
# 8  0.274104  0.725896           1    Pachuca  Santos Laguna 2025-01-20
#
#       Apuesta
# 0    0.000000
# 1    0.000000
# 2  125.472658
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# 7  124.988163
# 8  149.539180

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Cruz Azul").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#           team     opponent       date venue   time  \
# 634  Cruz Azul       Santos 2023-08-20  Home  18:00
# 635  Cruz Azul      Pachuca 2023-08-23  Away  20:06
# 636  Cruz Azul    Monterrey 2023-08-27  Away  21:05
# 637  Cruz Azul      América 2023-09-02  Home  22:10
# 638  Cruz Azul     Mazatlán 2023-09-15  Away  18:50
# 639  Cruz Azul    Querétaro 2023-09-24  Home  17:00
# 640  Cruz Azul     Atlético 2023-09-29  Away  22:00
# 641  Cruz Azul       Necaxa 2023-10-04  Away  20:00
# 642  Cruz Azul         UNAM 2023-10-07  Home  22:10
# 643  Cruz Azul         UANL 2023-10-21  Away  22:10
# 644  Cruz Azul         León 2023-10-28  Home  18:00
# 645  Cruz Azul    FC Juárez 2023-11-01  Home  19:00
# 646  Cruz Azul  Guadalajara 2023-11-04  Away  21:05
# 647  Cruz Azul       Puebla 2023-11-12  Home  18:00
# 648  Cruz Azul      Pachuca 2024-01-13  Home  19:00
# 649  Cruz Azul    FC Juárez 2024-01-19  Away  20:10
# 650  Cruz Azul     Mazatlán 2024-01-27  Home  17:00
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas\\_libs\\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: '2 (3)'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
matches_rolling

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
